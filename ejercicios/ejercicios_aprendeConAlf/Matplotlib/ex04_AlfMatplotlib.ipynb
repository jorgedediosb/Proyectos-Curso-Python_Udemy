# %% [markdown]
# Ejercicios página https://aprendeconalf.es/docencia/python/ejercicios/
#
# 04. Escribir una función que reciba una serie de Pandas con el número de ventas de un producto durante los meses de un trimestre y un título y cree un diagrama de sectores con las ventas en formato png con el titulo dado. El diagrama debe guardarse en un fichero con formato png y el título dado.

# %%
import pandas as pd
import matplotlib.pyplot as mpl

# %%
def diagrama_ventas(ventas, titulo):
    fig,ax = mpl.subplots()
    ventas.plot(kind='pie', ax=ax)
    mpl.ylabel('')
    mpl.title(titulo)
    mpl.savefig(titulo + '.png')
    return

# %%
ventas = {'enero':25, 'febrero':32, 'marzo':21}

# %%
ventas = pd.Series(ventas)

# %%
diagrama_ventas(ventas, 'ex04_Ventas 1er trimestre')
